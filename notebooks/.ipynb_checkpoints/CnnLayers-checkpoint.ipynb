# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import pickle
import numpy as np
from tensorflow.keras.callbacks import TensorBoard
import time
# Out:
# 2025-12-01 01:34:24.747813: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-01 01:34:25.119542: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-01 01:34:27.603824: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        print(f"GPUs detected and configured: {gpus[0].name}")
    except RuntimeError as e:
        print(e)
else:
    print("No GPU detected. Falling back to CPU.")

X = pickle.load(open("/home/nigga/engine/X.pickle", "rb"))
y = pickle.load(open("/home/nigga/engine/y.pickle", "rb"))

X = X / 255.0
dense_layer = 2
layer_size = 256
conv_layer = 3

NAME="{}-conv-{}-nodes-{}-dense-{}".format(conv_layer,layer_size,dense_layer,int(time.time()))
tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
print(NAME)

model = Sequential()            
model.add(Conv2D(256, (3,3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
for l in range(conv_layer-1): 
    model.add(Conv2D(layer_size, (3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
for l in range(dense_layer):
    model.add(Dense(layer_size))
    model.add(Activation('relu'))
model.add(Dense(1, activation='sigmoid'))            
# Compile
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

X = np.array(X)
y = np.array(y)
model.fit(X, y, batch_size=32, epochs=20, validation_split=0.3,callbacks=[tensorboard])
# Out:
# GPUs detected and configured: /physical_device:GPU:0
# 3-conv-256-nodes-2-dense-1764549430
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764549431.360217  244102 gpu_process_state.cc:208] Using CUDA malloc Async allocator for GPU: 0
# I0000 00:00:1764549431.361646  244102 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3584 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/20
# 2025-12-01 01:37:17.002170: I external/local_xla/xla/service/service.cc:163] XLA service 0x7fae64006510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-01 01:37:17.002236: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2025-12-01 01:37:17.048169: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-01 01:37:17.393513: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 2025-12-01 01:37:17.442724: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-01 01:37:17.442783: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-01 01:37:18.177791: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_374', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-12-01 01:37:18.497925: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_750', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-12-01 01:37:19.176698: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_750', 476 bytes spill stores, 476 bytes spill loads
#
# 2025-12-01 01:37:19.311525: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_748', 520 bytes spill stores, 520 bytes spill loads
#
# 2025-12-01 01:37:23.287537: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng12{k11=2} for conv (f32[32,256,37,37]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,39,39]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-01 01:37:23.453481: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.190925172s
# Trying algorithm eng12{k11=2} for conv (f32[32,256,37,37]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,39,39]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
#   1/479 ━━━━━━━━━━━━━━━━━━━━ 1:45:02 13s/step - accuracy: 0.4375 - loss: 0.6935
# I0000 00:00:1764549448.694634  244297 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.6253 - loss: 0.6506 - val_accuracy: 0.6386 - val_loss: 0.6472
# Epoch 2/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.7100 - loss: 0.5721 - val_accuracy: 0.6632 - val_loss: 0.6374
# Epoch 3/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.7757 - loss: 0.4684 - val_accuracy: 0.7452 - val_loss: 0.5329
# Epoch 4/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - accuracy: 0.8118 - loss: 0.4104 - val_accuracy: 0.8041 - val_loss: 0.4170
# Epoch 5/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - accuracy: 0.8454 - loss: 0.3508 - val_accuracy: 0.8166 - val_loss: 0.4062
# Epoch 6/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 26s 55ms/step - accuracy: 0.8749 - loss: 0.2873 - val_accuracy: 0.8258 - val_loss: 0.3916
# Epoch 7/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 41s 85ms/step - accuracy: 0.9037 - loss: 0.2317 - val_accuracy: 0.8323 - val_loss: 0.4087
# Epoch 8/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 37s 77ms/step - accuracy: 0.9304 - loss: 0.1699 - val_accuracy: 0.8334 - val_loss: 0.4827
# Epoch 9/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 29s 60ms/step - accuracy: 0.9513 - loss: 0.1231 - val_accuracy: 0.8378 - val_loss: 0.5002
# Epoch 10/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 33s 68ms/step - accuracy: 0.9683 - loss: 0.0842 - val_accuracy: 0.8416 - val_loss: 0.5470
# Epoch 11/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 42s 87ms/step - accuracy: 0.9785 - loss: 0.0579 - val_accuracy: 0.8326 - val_loss: 0.7071
# Epoch 12/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 54s 113ms/step - accuracy: 0.9835 - loss: 0.0484 - val_accuracy: 0.8131 - val_loss: 0.8395
# Epoch 13/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 37s 77ms/step - accuracy: 0.9846 - loss: 0.0444 - val_accuracy: 0.8256 - val_loss: 0.8014
# Epoch 14/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 74s 155ms/step - accuracy: 0.9899 - loss: 0.0289 - val_accuracy: 0.8224 - val_loss: 0.9374
# Epoch 15/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 81s 170ms/step - accuracy: 0.9863 - loss: 0.0360 - val_accuracy: 0.8355 - val_loss: 0.9092
# Epoch 16/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 31s 63ms/step - accuracy: 0.9889 - loss: 0.0331 - val_accuracy: 0.8255 - val_loss: 0.8376
# Epoch 17/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - accuracy: 0.9909 - loss: 0.0268 - val_accuracy: 0.8311 - val_loss: 0.8457
# Epoch 18/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.9922 - loss: 0.0236 - val_accuracy: 0.8298 - val_loss: 0.8964
# Epoch 19/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.9901 - loss: 0.0306 - val_accuracy: 0.8358 - val_loss: 0.8679
# Epoch 20/20
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.9943 - loss: 0.0184 - val_accuracy: 0.8366 - val_loss: 0.9720

# %%
model.save("cat_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
model = load_model("cat_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

IMG_PATH = "/home/nigga/engine/data/cats/Dog/100.jpg"
IMG_SIZE = 80  # must match your training images

# Load image in grayscale
img = cv2.imread(IMG_PATH, cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')  # Grayscale colormap
plt.title("Cat/Dog Image")
plt.axis('off')
plt.show()
img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))

img = img / 255.0

img = np.reshape(img, (1, IMG_SIZE, IMG_SIZE, 1))

prediction = model.predict(img)[0][0]
print("Raw prediction:", prediction)
print("Class:", "Cat" if prediction > 0.5 else "Dog")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ -0s -468159us/step
# Raw prediction: 1.2551032e-05
# Class: Dog
