# %%
import json
from validation.config_validator import validate_model_config

with open("config/model_config.json") as f:
    config = json.load(f)

validate_model_config(config)
print("Config is valid ✅")
# Out:
# Config is valid ✅
